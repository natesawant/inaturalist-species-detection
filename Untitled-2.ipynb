# %%
import torch

from efficient_pipeline import EfficientNetPipeline
from inaturalist import FISH_CLASSES

# %%
pipeline = EfficientNetPipeline(
                image_size=128,
                batch_size=64,
                learning_rate=0.001,
                num_epochs=40,
                top_k=5,
                model_type="efficient",
                classes=FISH_CLASSES
            )
# Out:
# WARNING: Using CPU architecture

# %%
pipeline.job_id = "latest"

# %%
pipeline.data_setup(False, FISH_CLASSES)
pipeline.load_model()
# Out:
# [INFO]: Loading pre-trained weights
# [INFO]: Fine-tuning all layers...
# Loading model from models/model_efficient_fish_latest.pt
# /home/nates/repos/inaturalist-species-detection/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/nates/repos/inaturalist-species-detection/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
pipeline.evaluate()
# Out:
# (50.20100502512563, 73.81909547738694)

# %%
y_true = []
y_pred = []

for images, labels in pipeline.test_dataloader:
    images = images.to(pipeline.device)
    labels = labels.to(pipeline.device)
    outputs = pipeline.model(images)
    _, predictions = torch.topk(outputs.data, k=pipeline.k, dim=1, largest=True)
    _, predicted = torch.max(outputs.data, 1)
    
    y_true += labels.tolist()
    y_pred += predicted.tolist()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from inaturalist import iNaturalistDataset

test = iNaturalistDataset(
    root="./data",
    train=False,
    download=False,
    classes=FISH_CLASSES,
    transform=pipeline.all_transforms,
)

# %%
import json

with open("data/train.json") as f:
    data = json.load(f)

# %%
data["categories"]
# Out:
# [{'id': 0,
#   'name': 'Lumbricus terrestris',
#   'common_name': 'Common Earthworm',
#   'supercategory': 'Animalia',
#   'kingdom': 'Animalia',
#   'phylum': 'Annelida',
#   'class': 'Clitellata',
#   'order': 'Haplotaxida',
#   'family': 'Lumbricidae',
#   'genus': 'Lumbricus',
#   'specific_epithet': 'terrestris',
#   'image_dir_name': '00000_Animalia_Annelida_Clitellata_Haplotaxida_Lumbricidae_Lumbricus_terrestris'},
#  {'id': 1,
#   'name': 'Sabella spallanzanii',
#   'common_name': 'Mediterranean Fanworm',
#   'supercategory': 'Animalia',
#   'kingdom': 'Animalia',
#   'phylum': 'Annelida',
#   'class': 'Polychaeta',
#   'order': 'Sabellida',
#   'family': 'Sabellidae',
#   'genus': 'Sabella',
#   'specific_epithet': 'spallanzanii',
#   'image_dir_name': '00001_Animalia_Annelida_Polychaeta_Sabellida_Sabellidae_Sabella_spallanzanii'},
#  {'id': 2,
#   'name': 'Serpula columbiana',
#   'common_name': 'Serpula columbiana',
#   'supercategory': 'Animalia',
#   'kingdom': 'Animalia',
#   'phylum': 'Annelida',
#   'class': 'Polychaeta',
#   'order': 'Sabellida',
#   'family': 'Serpulidae',
#   'genus': 'Serpula',
#   'specific_epithet': 'columbiana',
#   'image_dir_name': '00002_Animalia_Annelida_Polychaeta_Sabellida_Serpulidae_Serpula_columbiana'},
#  {'id': 3,
#   'name': 'Spirobranchus cariniferus',
#   'common_name': 'Blue Tube Worm',
#   'supercategory': 'Animalia',
#   'kingdom': 'Animalia',
#   'phylum': 'Annelida',
#   'class': 'Polychaeta',
#   'order': 'Sabellida',
#   'family': 'Serpulidae',
#   'genus': 'Spirobranchus',
#   'specific_epithet': 'cariniferus',
#   'image_dir_name': '00003_Animalia_Annelida_Polychaeta_Sabellida_Serpulidae_Spirobranchus_cariniferus'},
#  {'id': 4,
#   'name': 'Eratigena duellica',
#   'common_name': 'Giant House Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Agelenidae',
#   'genus': 'Eratigena',
#   'specific_epithet': 'duellica',
#   'image_dir_name': '00004_Animalia_Arthropoda_Arachnida_Araneae_Agelenidae_Eratigena_duellica'},
#  {'id': 5,
#   'name': 'Atypoides riversi',
#   'common_name': 'California Turret Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Antrodiaetidae',
#   'genus': 'Atypoides',
#   'specific_epithet': 'riversi',
#   'image_dir_name': '00005_Animalia_Arthropoda_Arachnida_Araneae_Antrodiaetidae_Atypoides_riversi'},
#  {'id': 6,
#   'name': 'Aculepeira ceropegia',
#   'common_name': 'Oak Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Aculepeira',
#   'specific_epithet': 'ceropegia',
#   'image_dir_name': '00006_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Aculepeira_ceropegia'},
#  {'id': 7,
#   'name': 'Agalenatea redii',
#   'common_name': 'Gorse Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Agalenatea',
#   'specific_epithet': 'redii',
#   'image_dir_name': '00007_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Agalenatea_redii'},
#  {'id': 8,
#   'name': 'Araneus bicentenarius',
#   'common_name': 'Giant Lichen Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Araneus',
#   'specific_epithet': 'bicentenarius',
#   'image_dir_name': '00008_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Araneus_bicentenarius'},
#  {'id': 9,
#   'name': 'Araneus diadematus',
#   'common_name': 'Cross Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Araneus',
#   'specific_epithet': 'diadematus',
#   'image_dir_name': '00009_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Araneus_diadematus'},
#  {'id': 10,
#   'name': 'Araneus marmoreus',
#   'common_name': 'Marbled Orb Weaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Araneus',
#   'specific_epithet': 'marmoreus',
#   'image_dir_name': '00010_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Araneus_marmoreus'},
#  {'id': 11,
#   'name': 'Araneus quadratus',
#   'common_name': 'Four-spot Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Araneus',
#   'specific_epithet': 'quadratus',
#   'image_dir_name': '00011_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Araneus_quadratus'},
#  {'id': 12,
#   'name': 'Araneus trifolium',
#   'common_name': 'Shamrock Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Araneus',
#   'specific_epithet': 'trifolium',
#   'image_dir_name': '00012_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Araneus_trifolium'},
#  {'id': 13,
#   'name': 'Araniella displicata',
#   'common_name': 'Six-spotted Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Araniella',
#   'specific_epithet': 'displicata',
#   'image_dir_name': '00013_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Araniella_displicata'},
#  {'id': 14,
#   'name': 'Argiope appensa',
#   'common_name': 'Hawaiian Garden Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'appensa',
#   'image_dir_name': '00014_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_appensa'},
#  {'id': 15,
#   'name': 'Argiope argentata',
#   'common_name': 'Silver Garden Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'argentata',
#   'image_dir_name': '00015_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_argentata'},
#  {'id': 16,
#   'name': 'Argiope aurantia',
#   'common_name': 'Yellow Garden Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'aurantia',
#   'image_dir_name': '00016_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_aurantia'},
#  {'id': 17,
#   'name': 'Argiope australis',
#   'common_name': 'Common Garden Orbweb Spinner',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'australis',
#   'image_dir_name': '00017_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_australis'},
#  {'id': 18,
#   'name': 'Argiope bruennichi',
#   'common_name': 'Wasp Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'bruennichi',
#   'image_dir_name': '00018_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_bruennichi'},
#  {'id': 19,
#   'name': 'Argiope keyserlingi',
#   'common_name': "St. Andrew's Cross Spider",
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'keyserlingi',
#   'image_dir_name': '00019_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_keyserlingi'},
#  {'id': 20,
#   'name': 'Argiope lobata',
#   'common_name': 'Lobed Argiope',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'lobata',
#   'image_dir_name': '00020_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_lobata'},
#  {'id': 21,
#   'name': 'Argiope trifasciata',
#   'common_name': 'Banded Garden Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Argiope',
#   'specific_epithet': 'trifasciata',
#   'image_dir_name': '00021_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Argiope_trifasciata'},
#  {'id': 22,
#   'name': 'Austracantha minax',
#   'common_name': 'Australian Jewel Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Austracantha',
#   'specific_epithet': 'minax',
#   'image_dir_name': '00022_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Austracantha_minax'},
#  {'id': 23,
#   'name': 'Cyclosa conica',
#   'common_name': 'Conical Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Cyclosa',
#   'specific_epithet': 'conica',
#   'image_dir_name': '00023_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Cyclosa_conica'},
#  {'id': 24,
#   'name': 'Cyclosa turbinata',
#   'common_name': 'Humped Trashline Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Cyclosa',
#   'specific_epithet': 'turbinata',
#   'image_dir_name': '00024_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Cyclosa_turbinata'},
#  {'id': 25,
#   'name': 'Cyrtophora citricola',
#   'common_name': 'Tropical Tent-web Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Cyrtophora',
#   'specific_epithet': 'citricola',
#   'image_dir_name': '00025_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Cyrtophora_citricola'},
#  {'id': 26,
#   'name': 'Eriophora pustulosa',
#   'common_name': 'Garden Orbweb Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Eriophora',
#   'specific_epithet': 'pustulosa',
#   'image_dir_name': '00026_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Eriophora_pustulosa'},
#  {'id': 27,
#   'name': 'Eriophora ravilla',
#   'common_name': 'Tropical Orbweaver Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Eriophora',
#   'specific_epithet': 'ravilla',
#   'image_dir_name': '00027_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Eriophora_ravilla'},
#  {'id': 28,
#   'name': 'Gasteracantha cancriformis',
#   'common_name': 'Spinybacked Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Gasteracantha',
#   'specific_epithet': 'cancriformis',
#   'image_dir_name': '00028_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Gasteracantha_cancriformis'},
#  {'id': 29,
#   'name': 'Gasteracantha kuhli',
#   'common_name': 'Black-and-white Spiny Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Gasteracantha',
#   'specific_epithet': 'kuhli',
#   'image_dir_name': '00029_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Gasteracantha_kuhli'},
#  {'id': 30,
#   'name': 'Larinioides cornutus',
#   'common_name': 'Furrow Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Larinioides',
#   'specific_epithet': 'cornutus',
#   'image_dir_name': '00030_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Larinioides_cornutus'},
#  {'id': 31,
#   'name': 'Mangora acalypha',
#   'common_name': 'Cricket-bat Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Mangora',
#   'specific_epithet': 'acalypha',
#   'image_dir_name': '00031_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Mangora_acalypha'},
#  {'id': 32,
#   'name': 'Mangora placida',
#   'common_name': 'Tuft-legged Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Mangora',
#   'specific_epithet': 'placida',
#   'image_dir_name': '00032_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Mangora_placida'},
#  {'id': 33,
#   'name': 'Mecynogea lemniscata',
#   'common_name': 'Basilica Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Mecynogea',
#   'specific_epithet': 'lemniscata',
#   'image_dir_name': '00033_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Mecynogea_lemniscata'},
#  {'id': 34,
#   'name': 'Micrathena gracilis',
#   'common_name': 'Spined Micrathena',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Micrathena',
#   'specific_epithet': 'gracilis',
#   'image_dir_name': '00034_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Micrathena_gracilis'},
#  {'id': 35,
#   'name': 'Micrathena mitrata',
#   'common_name': 'White Micrathena',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Micrathena',
#   'specific_epithet': 'mitrata',
#   'image_dir_name': '00035_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Micrathena_mitrata'},
#  {'id': 36,
#   'name': 'Micrathena sagittata',
#   'common_name': 'Arrow-shaped Micrathena',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Micrathena',
#   'specific_epithet': 'sagittata',
#   'image_dir_name': '00036_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Micrathena_sagittata'},
#  {'id': 37,
#   'name': 'Neoscona arabesca',
#   'common_name': 'Arabesque Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Neoscona',
#   'specific_epithet': 'arabesca',
#   'image_dir_name': '00037_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Neoscona_arabesca'},
#  {'id': 38,
#   'name': 'Neoscona crucifera',
#   'common_name': "Hentz's Orbweaver",
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Neoscona',
#   'specific_epithet': 'crucifera',
#   'image_dir_name': '00038_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Neoscona_crucifera'},
#  {'id': 39,
#   'name': 'Neoscona domiciliorum',
#   'common_name': 'Red-femured Spotted Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Neoscona',
#   'specific_epithet': 'domiciliorum',
#   'image_dir_name': '00039_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Neoscona_domiciliorum'},
#  {'id': 40,
#   'name': 'Neoscona oaxacensis',
#   'common_name': 'Western Spotted Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Neoscona',
#   'specific_epithet': 'oaxacensis',
#   'image_dir_name': '00040_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Neoscona_oaxacensis'},
#  {'id': 41,
#   'name': 'Nephila pilipes',
#   'common_name': 'Giant Golden Orb-weaving Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Nephila',
#   'specific_epithet': 'pilipes',
#   'image_dir_name': '00041_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Nephila_pilipes'},
#  {'id': 42,
#   'name': 'Nuctenea umbratica',
#   'common_name': 'Walnut Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Nuctenea',
#   'specific_epithet': 'umbratica',
#   'image_dir_name': '00042_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Nuctenea_umbratica'},
#  {'id': 43,
#   'name': 'Thelacantha brevispina',
#   'common_name': 'Asian Spinybacked Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Thelacantha',
#   'specific_epithet': 'brevispina',
#   'image_dir_name': '00043_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Thelacantha_brevispina'},
#  {'id': 44,
#   'name': 'Trichonephila clavata',
#   'common_name': 'Jorō Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Trichonephila',
#   'specific_epithet': 'clavata',
#   'image_dir_name': '00044_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Trichonephila_clavata'},
#  {'id': 45,
#   'name': 'Trichonephila clavipes',
#   'common_name': 'Golden Silk Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Trichonephila',
#   'specific_epithet': 'clavipes',
#   'image_dir_name': '00045_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Trichonephila_clavipes'},
#  {'id': 46,
#   'name': 'Trichonephila edulis',
#   'common_name': 'Edible Golden Silk Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Trichonephila',
#   'specific_epithet': 'edulis',
#   'image_dir_name': '00046_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Trichonephila_edulis'},
#  {'id': 47,
#   'name': 'Trichonephila fenestrata',
#   'common_name': 'Hairy Golden Orb-weaving Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Trichonephila',
#   'specific_epithet': 'fenestrata',
#   'image_dir_name': '00047_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Trichonephila_fenestrata'},
#  {'id': 48,
#   'name': 'Trichonephila plumipes',
#   'common_name': 'Tiger Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Trichonephila',
#   'specific_epithet': 'plumipes',
#   'image_dir_name': '00048_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Trichonephila_plumipes'},
#  {'id': 49,
#   'name': 'Verrucosa arenata',
#   'common_name': 'Arrowhead Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Verrucosa',
#   'specific_epithet': 'arenata',
#   'image_dir_name': '00049_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Verrucosa_arenata'},
#  {'id': 50,
#   'name': 'Zygiella x-notata',
#   'common_name': 'Silver-sided Sector Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Araneidae',
#   'genus': 'Zygiella',
#   'specific_epithet': 'x-notata',
#   'image_dir_name': '00050_Animalia_Arthropoda_Arachnida_Araneae_Araneidae_Zygiella_x-notata'},
#  {'id': 51,
#   'name': 'Cheiracanthium mildei',
#   'common_name': 'Yellow Sac Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Cheiracanthiidae',
#   'genus': 'Cheiracanthium',
#   'specific_epithet': 'mildei',
#   'image_dir_name': '00051_Animalia_Arthropoda_Arachnida_Araneae_Cheiracanthiidae_Cheiracanthium_mildei'},
#  {'id': 52,
#   'name': 'Nyssus coloripes',
#   'common_name': 'Spotted ground swift',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Corinnidae',
#   'genus': 'Nyssus',
#   'specific_epithet': 'coloripes',
#   'image_dir_name': '00052_Animalia_Arthropoda_Arachnida_Araneae_Corinnidae_Nyssus_coloripes'},
#  {'id': 53,
#   'name': 'Badumna longinqua',
#   'common_name': 'Grey House Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Desidae',
#   'genus': 'Badumna',
#   'specific_epithet': 'longinqua',
#   'image_dir_name': '00053_Animalia_Arthropoda_Arachnida_Araneae_Desidae_Badumna_longinqua'},
#  {'id': 54,
#   'name': 'Dysdera crocata',
#   'common_name': 'Woodlouse Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Dysderidae',
#   'genus': 'Dysdera',
#   'specific_epithet': 'crocata',
#   'image_dir_name': '00054_Animalia_Arthropoda_Arachnida_Araneae_Dysderidae_Dysdera_crocata'},
#  {'id': 55,
#   'name': 'Kukulcania hibernalis',
#   'common_name': 'Southern House Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Filistatidae',
#   'genus': 'Kukulcania',
#   'specific_epithet': 'hibernalis',
#   'image_dir_name': '00055_Animalia_Arthropoda_Arachnida_Araneae_Filistatidae_Kukulcania_hibernalis'},
#  {'id': 56,
#   'name': 'Herpyllus ecclesiasticus',
#   'common_name': 'Parson Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Gnaphosidae',
#   'genus': 'Herpyllus',
#   'specific_epithet': 'ecclesiasticus',
#   'image_dir_name': '00056_Animalia_Arthropoda_Arachnida_Araneae_Gnaphosidae_Herpyllus_ecclesiasticus'},
#  {'id': 57,
#   'name': 'Frontinella pyramitela',
#   'common_name': 'Bowl and Doily Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Linyphiidae',
#   'genus': 'Frontinella',
#   'specific_epithet': 'pyramitela',
#   'image_dir_name': '00057_Animalia_Arthropoda_Arachnida_Araneae_Linyphiidae_Frontinella_pyramitela'},
#  {'id': 58,
#   'name': 'Neriene radiata',
#   'common_name': 'Filmy Dome Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Linyphiidae',
#   'genus': 'Neriene',
#   'specific_epithet': 'radiata',
#   'image_dir_name': '00058_Animalia_Arthropoda_Arachnida_Araneae_Linyphiidae_Neriene_radiata'},
#  {'id': 59,
#   'name': 'Hogna radiata',
#   'common_name': 'Radiated Wolf Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Lycosidae',
#   'genus': 'Hogna',
#   'specific_epithet': 'radiata',
#   'image_dir_name': '00059_Animalia_Arthropoda_Arachnida_Araneae_Lycosidae_Hogna_radiata'},
#  {'id': 60,
#   'name': 'Rabidosa rabida',
#   'common_name': 'Rabid Wolf Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Lycosidae',
#   'genus': 'Rabidosa',
#   'specific_epithet': 'rabida',
#   'image_dir_name': '00060_Animalia_Arthropoda_Arachnida_Araneae_Lycosidae_Rabidosa_rabida'},
#  {'id': 61,
#   'name': 'Oxyopes salticus',
#   'common_name': 'Striped Lynx Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Oxyopidae',
#   'genus': 'Oxyopes',
#   'specific_epithet': 'salticus',
#   'image_dir_name': '00061_Animalia_Arthropoda_Arachnida_Araneae_Oxyopidae_Oxyopes_salticus'},
#  {'id': 62,
#   'name': 'Oxyopes scalaris',
#   'common_name': 'Western Lynx Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Oxyopidae',
#   'genus': 'Oxyopes',
#   'specific_epithet': 'scalaris',
#   'image_dir_name': '00062_Animalia_Arthropoda_Arachnida_Araneae_Oxyopidae_Oxyopes_scalaris'},
#  {'id': 63,
#   'name': 'Peucetia viridans',
#   'common_name': 'Green Lynx Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Oxyopidae',
#   'genus': 'Peucetia',
#   'specific_epithet': 'viridans',
#   'image_dir_name': '00063_Animalia_Arthropoda_Arachnida_Araneae_Oxyopidae_Peucetia_viridans'},
#  {'id': 64,
#   'name': 'Holocnemus pluchei',
#   'common_name': 'Marbled Cellar Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pholcidae',
#   'genus': 'Holocnemus',
#   'specific_epithet': 'pluchei',
#   'image_dir_name': '00064_Animalia_Arthropoda_Arachnida_Araneae_Pholcidae_Holocnemus_pluchei'},
#  {'id': 65,
#   'name': 'Pholcus phalangioides',
#   'common_name': 'Skull Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pholcidae',
#   'genus': 'Pholcus',
#   'specific_epithet': 'phalangioides',
#   'image_dir_name': '00065_Animalia_Arthropoda_Arachnida_Araneae_Pholcidae_Pholcus_phalangioides'},
#  {'id': 66,
#   'name': 'Dolomedes albineus',
#   'common_name': 'Whitebanded Fishing Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Dolomedes',
#   'specific_epithet': 'albineus',
#   'image_dir_name': '00066_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Dolomedes_albineus'},
#  {'id': 67,
#   'name': 'Dolomedes minor',
#   'common_name': 'Nurseryweb Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Dolomedes',
#   'specific_epithet': 'minor',
#   'image_dir_name': '00067_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Dolomedes_minor'},
#  {'id': 68,
#   'name': 'Dolomedes scriptus',
#   'common_name': 'Striped Fishing Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Dolomedes',
#   'specific_epithet': 'scriptus',
#   'image_dir_name': '00068_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Dolomedes_scriptus'},
#  {'id': 69,
#   'name': 'Dolomedes tenebrosus',
#   'common_name': 'Dark Fishing Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Dolomedes',
#   'specific_epithet': 'tenebrosus',
#   'image_dir_name': '00069_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Dolomedes_tenebrosus'},
#  {'id': 70,
#   'name': 'Dolomedes triton',
#   'common_name': 'Six-spotted Fishing Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Dolomedes',
#   'specific_epithet': 'triton',
#   'image_dir_name': '00070_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Dolomedes_triton'},
#  {'id': 71,
#   'name': 'Pisaura mirabilis',
#   'common_name': 'European Nursery Web spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Pisaura',
#   'specific_epithet': 'mirabilis',
#   'image_dir_name': '00071_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Pisaura_mirabilis'},
#  {'id': 72,
#   'name': 'Pisaurina mira',
#   'common_name': 'American Nursery Web Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Pisauridae',
#   'genus': 'Pisaurina',
#   'specific_epithet': 'mira',
#   'image_dir_name': '00072_Animalia_Arthropoda_Arachnida_Araneae_Pisauridae_Pisaurina_mira'},
#  {'id': 73,
#   'name': 'Anasaitis canosa',
#   'common_name': 'Twinflagged Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Anasaitis',
#   'specific_epithet': 'canosa',
#   'image_dir_name': '00073_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Anasaitis_canosa'},
#  {'id': 74,
#   'name': 'Attulus fasciger',
#   'common_name': 'Asiatic Wall Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Attulus',
#   'specific_epithet': 'fasciger',
#   'image_dir_name': '00074_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Attulus_fasciger'},
#  {'id': 75,
#   'name': 'Colonus hesperus',
#   'common_name': 'Colonus hesperus',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Colonus',
#   'specific_epithet': 'hesperus',
#   'image_dir_name': '00075_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Colonus_hesperus'},
#  {'id': 76,
#   'name': 'Colonus sylvanus',
#   'common_name': 'Sylvan Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Colonus',
#   'specific_epithet': 'sylvanus',
#   'image_dir_name': '00076_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Colonus_sylvanus'},
#  {'id': 77,
#   'name': 'Eris militaris',
#   'common_name': 'Bronze Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Eris',
#   'specific_epithet': 'militaris',
#   'image_dir_name': '00077_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Eris_militaris'},
#  {'id': 78,
#   'name': 'Hasarius adansoni',
#   'common_name': "Adanson's House Jumper",
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Hasarius',
#   'specific_epithet': 'adansoni',
#   'image_dir_name': '00078_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Hasarius_adansoni'},
#  {'id': 79,
#   'name': 'Helpis minitabunda',
#   'common_name': 'Bronze hopper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Helpis',
#   'specific_epithet': 'minitabunda',
#   'image_dir_name': '00079_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Helpis_minitabunda'},
#  {'id': 80,
#   'name': 'Hentzia mitrata',
#   'common_name': 'White-jawed Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Hentzia',
#   'specific_epithet': 'mitrata',
#   'image_dir_name': '00080_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Hentzia_mitrata'},
#  {'id': 81,
#   'name': 'Hentzia palmarum',
#   'common_name': 'Common Hentz Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Hentzia',
#   'specific_epithet': 'palmarum',
#   'image_dir_name': '00081_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Hentzia_palmarum'},
#  {'id': 82,
#   'name': 'Hypoblemum griseum',
#   'common_name': 'White banded house jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Hypoblemum',
#   'specific_epithet': 'griseum',
#   'image_dir_name': '00082_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Hypoblemum_griseum'},
#  {'id': 83,
#   'name': 'Lyssomanes viridis',
#   'common_name': 'Magnolia Green Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Lyssomanes',
#   'specific_epithet': 'viridis',
#   'image_dir_name': '00083_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Lyssomanes_viridis'},
#  {'id': 84,
#   'name': 'Maevia inclemens',
#   'common_name': 'Dimorphic Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Maevia',
#   'specific_epithet': 'inclemens',
#   'image_dir_name': '00084_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Maevia_inclemens'},
#  {'id': 85,
#   'name': 'Marpissa muscosa',
#   'common_name': 'Fencepost jumping spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Marpissa',
#   'specific_epithet': 'muscosa',
#   'image_dir_name': '00085_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Marpissa_muscosa'},
#  {'id': 86,
#   'name': 'Menemerus bivittatus',
#   'common_name': 'Gray Wall Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Menemerus',
#   'specific_epithet': 'bivittatus',
#   'image_dir_name': '00086_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Menemerus_bivittatus'},
#  {'id': 87,
#   'name': 'Menemerus semilimbatus',
#   'common_name': 'Menemerus semilimbatus',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Menemerus',
#   'specific_epithet': 'semilimbatus',
#   'image_dir_name': '00087_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Menemerus_semilimbatus'},
#  {'id': 88,
#   'name': 'Metacyrba taeniola',
#   'common_name': 'Ribbon Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Metacyrba',
#   'specific_epithet': 'taeniola',
#   'image_dir_name': '00088_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Metacyrba_taeniola'},
#  {'id': 89,
#   'name': 'Naphrys pulex',
#   'common_name': 'Flea Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Naphrys',
#   'specific_epithet': 'pulex',
#   'image_dir_name': '00089_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Naphrys_pulex'},
#  {'id': 90,
#   'name': 'Paraphidippus aurantius',
#   'common_name': 'Golden Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Paraphidippus',
#   'specific_epithet': 'aurantius',
#   'image_dir_name': '00090_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Paraphidippus_aurantius'},
#  {'id': 91,
#   'name': 'Pelegrina galathea',
#   'common_name': 'Peppered Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Pelegrina',
#   'specific_epithet': 'galathea',
#   'image_dir_name': '00091_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Pelegrina_galathea'},
#  {'id': 92,
#   'name': 'Phidippus audax',
#   'common_name': 'Bold Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Phidippus',
#   'specific_epithet': 'audax',
#   'image_dir_name': '00092_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Phidippus_audax'},
#  {'id': 93,
#   'name': 'Phidippus clarus',
#   'common_name': 'Brilliant Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Phidippus',
#   'specific_epithet': 'clarus',
#   'image_dir_name': '00093_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Phidippus_clarus'},
#  {'id': 94,
#   'name': 'Phidippus johnsoni',
#   'common_name': "Johnson's Jumping Spider",
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Phidippus',
#   'specific_epithet': 'johnsoni',
#   'image_dir_name': '00094_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Phidippus_johnsoni'},
#  {'id': 95,
#   'name': 'Philaeus chrysops',
#   'common_name': 'Red-bellied Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Philaeus',
#   'specific_epithet': 'chrysops',
#   'image_dir_name': '00095_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Philaeus_chrysops'},
#  {'id': 96,
#   'name': 'Platycryptus undatus',
#   'common_name': 'Tan Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Platycryptus',
#   'specific_epithet': 'undatus',
#   'image_dir_name': '00096_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Platycryptus_undatus'},
#  {'id': 97,
#   'name': 'Plexippus paykulli',
#   'common_name': 'Pantropical Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Plexippus',
#   'specific_epithet': 'paykulli',
#   'image_dir_name': '00097_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Plexippus_paykulli'},
#  {'id': 98,
#   'name': 'Salticus scenicus',
#   'common_name': 'Zebra Jumper',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Salticus',
#   'specific_epithet': 'scenicus',
#   'image_dir_name': '00098_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Salticus_scenicus'},
#  {'id': 99,
#   'name': 'Sassacus vitis',
#   'common_name': 'Buttonhook Leaf-beetle Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Sassacus',
#   'specific_epithet': 'vitis',
#   'image_dir_name': '00099_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Sassacus_vitis'},
#  {'id': 100,
#   'name': 'Trite auricoma',
#   'common_name': 'Golden-brown Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Trite',
#   'specific_epithet': 'auricoma',
#   'image_dir_name': '00100_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Trite_auricoma'},
#  {'id': 101,
#   'name': 'Trite planiceps',
#   'common_name': 'Black-headed Jumping Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Salticidae',
#   'genus': 'Trite',
#   'specific_epithet': 'planiceps',
#   'image_dir_name': '00101_Animalia_Arthropoda_Arachnida_Araneae_Salticidae_Trite_planiceps'},
#  {'id': 102,
#   'name': 'Loxosceles reclusa',
#   'common_name': 'Brown Recluse',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Sicariidae',
#   'genus': 'Loxosceles',
#   'specific_epithet': 'reclusa',
#   'image_dir_name': '00102_Animalia_Arthropoda_Arachnida_Araneae_Sicariidae_Loxosceles_reclusa'},
#  {'id': 103,
#   'name': 'Heteropoda venatoria',
#   'common_name': 'Giant Crab Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Sparassidae',
#   'genus': 'Heteropoda',
#   'specific_epithet': 'venatoria',
#   'image_dir_name': '00103_Animalia_Arthropoda_Arachnida_Araneae_Sparassidae_Heteropoda_venatoria'},
#  {'id': 104,
#   'name': 'Micrommata virescens',
#   'common_name': 'Green Huntsman Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Sparassidae',
#   'genus': 'Micrommata',
#   'specific_epithet': 'virescens',
#   'image_dir_name': '00104_Animalia_Arthropoda_Arachnida_Araneae_Sparassidae_Micrommata_virescens'},
#  {'id': 105,
#   'name': 'Olios giganteus',
#   'common_name': 'Giant Crab Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Sparassidae',
#   'genus': 'Olios',
#   'specific_epithet': 'giganteus',
#   'image_dir_name': '00105_Animalia_Arthropoda_Arachnida_Araneae_Sparassidae_Olios_giganteus'},
#  {'id': 106,
#   'name': 'Leucauge argyra',
#   'common_name': 'Leucauge argyra',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Tetragnathidae',
#   'genus': 'Leucauge',
#   'specific_epithet': 'argyra',
#   'image_dir_name': '00106_Animalia_Arthropoda_Arachnida_Araneae_Tetragnathidae_Leucauge_argyra'},
#  {'id': 107,
#   'name': 'Leucauge argyrobapta',
#   'common_name': 'Mabel Orchard Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Tetragnathidae',
#   'genus': 'Leucauge',
#   'specific_epithet': 'argyrobapta',
#   'image_dir_name': '00107_Animalia_Arthropoda_Arachnida_Araneae_Tetragnathidae_Leucauge_argyrobapta'},
#  {'id': 108,
#   'name': 'Leucauge venusta',
#   'common_name': 'Orchard Orbweaver',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Tetragnathidae',
#   'genus': 'Leucauge',
#   'specific_epithet': 'venusta',
#   'image_dir_name': '00108_Animalia_Arthropoda_Arachnida_Araneae_Tetragnathidae_Leucauge_venusta'},
#  {'id': 109,
#   'name': 'Aphonopelma chalcodes',
#   'common_name': 'Desert Blonde Tarantula',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theraphosidae',
#   'genus': 'Aphonopelma',
#   'specific_epithet': 'chalcodes',
#   'image_dir_name': '00109_Animalia_Arthropoda_Arachnida_Araneae_Theraphosidae_Aphonopelma_chalcodes'},
#  {'id': 110,
#   'name': 'Aphonopelma eutylenum',
#   'common_name': 'California Ebony Tarantula',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theraphosidae',
#   'genus': 'Aphonopelma',
#   'specific_epithet': 'eutylenum',
#   'image_dir_name': '00110_Animalia_Arthropoda_Arachnida_Araneae_Theraphosidae_Aphonopelma_eutylenum'},
#  {'id': 111,
#   'name': 'Aphonopelma hentzi',
#   'common_name': 'Texas Brown Tarantula',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theraphosidae',
#   'genus': 'Aphonopelma',
#   'specific_epithet': 'hentzi',
#   'image_dir_name': '00111_Animalia_Arthropoda_Arachnida_Araneae_Theraphosidae_Aphonopelma_hentzi'},
#  {'id': 112,
#   'name': 'Aphonopelma iodius',
#   'common_name': 'Desert Tarantula',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theraphosidae',
#   'genus': 'Aphonopelma',
#   'specific_epithet': 'iodius',
#   'image_dir_name': '00112_Animalia_Arthropoda_Arachnida_Araneae_Theraphosidae_Aphonopelma_iodius'},
#  {'id': 113,
#   'name': 'Enoplognatha ovata',
#   'common_name': 'Common candy-striped spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Enoplognatha',
#   'specific_epithet': 'ovata',
#   'image_dir_name': '00113_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Enoplognatha_ovata'},
#  {'id': 114,
#   'name': 'Latrodectus geometricus',
#   'common_name': 'Brown Widow',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Latrodectus',
#   'specific_epithet': 'geometricus',
#   'image_dir_name': '00114_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Latrodectus_geometricus'},
#  {'id': 115,
#   'name': 'Latrodectus hasselti',
#   'common_name': 'Redback Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Latrodectus',
#   'specific_epithet': 'hasselti',
#   'image_dir_name': '00115_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Latrodectus_hasselti'},
#  {'id': 116,
#   'name': 'Latrodectus hesperus',
#   'common_name': 'Western Black Widow',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Latrodectus',
#   'specific_epithet': 'hesperus',
#   'image_dir_name': '00116_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Latrodectus_hesperus'},
#  {'id': 117,
#   'name': 'Latrodectus katipo',
#   'common_name': 'Katipō',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Latrodectus',
#   'specific_epithet': 'katipo',
#   'image_dir_name': '00117_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Latrodectus_katipo'},
#  {'id': 118,
#   'name': 'Latrodectus mactans',
#   'common_name': 'Southern Black Widow',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Latrodectus',
#   'specific_epithet': 'mactans',
#   'image_dir_name': '00118_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Latrodectus_mactans'},
#  {'id': 119,
#   'name': 'Latrodectus variolus',
#   'common_name': 'Northern Black Widow',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Latrodectus',
#   'specific_epithet': 'variolus',
#   'image_dir_name': '00119_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Latrodectus_variolus'},
#  {'id': 120,
#   'name': 'Parasteatoda tepidariorum',
#   'common_name': 'Common House Spider',
#   'supercategory': 'Arachnids',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Arachnida',
#   'order': 'Araneae',
#   'family': 'Theridiidae',
#   'genus': 'Parasteatoda',
#   'specific_epithet': 'tepidariorum',
#   'image_dir_name': '00120_Animalia_Arthropoda_Arachnida_Araneae_Theridiidae_Parasteatoda_tepidariorum'},
#  {'id': 121,
#   'name': 'Steatoda capensis',
# ...
#  {'id': 959,
#   'name': 'Pseudothyatira cymatophoroides',
#   'common_name': 'Tufted Thyatirid Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Drepanidae',
#   'genus': 'Pseudothyatira',
#   'specific_epithet': 'cymatophoroides',
#   'image_dir_name': '00959_Animalia_Arthropoda_Insecta_Lepidoptera_Drepanidae_Pseudothyatira_cymatophoroides'},
#  {'id': 960,
#   'name': 'Thyatira batis',
#   'common_name': 'Peach Blossom Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Drepanidae',
#   'genus': 'Thyatira',
#   'specific_epithet': 'batis',
#   'image_dir_name': '00960_Animalia_Arthropoda_Insecta_Lepidoptera_Drepanidae_Thyatira_batis'},
#  {'id': 961,
#   'name': 'Watsonalla binaria',
#   'common_name': 'Oak Hook-tip',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Drepanidae',
#   'genus': 'Watsonalla',
#   'specific_epithet': 'binaria',
#   'image_dir_name': '00961_Animalia_Arthropoda_Insecta_Lepidoptera_Drepanidae_Watsonalla_binaria'},
#  {'id': 962,
#   'name': 'Watsonalla cultraria',
#   'common_name': 'Barred Hook-tip',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Drepanidae',
#   'genus': 'Watsonalla',
#   'specific_epithet': 'cultraria',
#   'image_dir_name': '00962_Animalia_Arthropoda_Insecta_Lepidoptera_Drepanidae_Watsonalla_cultraria'},
#  {'id': 963,
#   'name': 'Achaea janata',
#   'common_name': 'Castor Semi-looper',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Achaea',
#   'specific_epithet': 'janata',
#   'image_dir_name': '00963_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Achaea_janata'},
#  {'id': 964,
#   'name': 'Allotria elonympha',
#   'common_name': 'False Underwing Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Allotria',
#   'specific_epithet': 'elonympha',
#   'image_dir_name': '00964_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Allotria_elonympha'},
#  {'id': 965,
#   'name': 'Amata huebneri',
#   'common_name': "Hübner's Wasp Moth",
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Amata',
#   'specific_epithet': 'huebneri',
#   'image_dir_name': '00965_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Amata_huebneri'},
#  {'id': 966,
#   'name': 'Amata phegea',
#   'common_name': 'Nine-spotted Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Amata',
#   'specific_epithet': 'phegea',
#   'image_dir_name': '00966_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Amata_phegea'},
#  {'id': 967,
#   'name': 'Anticarsia gemmatalis',
#   'common_name': 'Velvet Bean Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Anticarsia',
#   'specific_epithet': 'gemmatalis',
#   'image_dir_name': '00967_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Anticarsia_gemmatalis'},
#  {'id': 968,
#   'name': 'Apantesis arge',
#   'common_name': 'Arge Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'arge',
#   'image_dir_name': '00968_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_arge'},
#  {'id': 969,
#   'name': 'Apantesis ornata',
#   'common_name': 'Ornate Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'ornata',
#   'image_dir_name': '00969_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_ornata'},
#  {'id': 970,
#   'name': 'Apantesis parthenice',
#   'common_name': 'Parthenice Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'parthenice',
#   'image_dir_name': '00970_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_parthenice'},
#  {'id': 971,
#   'name': 'Apantesis phalerata',
#   'common_name': 'Harnessed Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'phalerata',
#   'image_dir_name': '00971_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_phalerata'},
#  {'id': 972,
#   'name': 'Apantesis proxima',
#   'common_name': 'Mexican Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'proxima',
#   'image_dir_name': '00972_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_proxima'},
#  {'id': 973,
#   'name': 'Apantesis virgo',
#   'common_name': 'Virgin Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'virgo',
#   'image_dir_name': '00973_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_virgo'},
#  {'id': 974,
#   'name': 'Apantesis virguncula',
#   'common_name': 'Little Virgin Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Apantesis',
#   'specific_epithet': 'virguncula',
#   'image_dir_name': '00974_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Apantesis_virguncula'},
#  {'id': 975,
#   'name': 'Arachnis picta',
#   'common_name': 'Painted Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Arachnis',
#   'specific_epithet': 'picta',
#   'image_dir_name': '00975_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Arachnis_picta'},
#  {'id': 976,
#   'name': 'Arctia caja',
#   'common_name': 'Garden Tiger',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Arctia',
#   'specific_epithet': 'caja',
#   'image_dir_name': '00976_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Arctia_caja'},
#  {'id': 977,
#   'name': 'Arctia parthenos',
#   'common_name': 'St. Lawrence Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Arctia',
#   'specific_epithet': 'parthenos',
#   'image_dir_name': '00977_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Arctia_parthenos'},
#  {'id': 978,
#   'name': 'Arctia plantaginis',
#   'common_name': 'Wood Tiger',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Arctia',
#   'specific_epithet': 'plantaginis',
#   'image_dir_name': '00978_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Arctia_plantaginis'},
#  {'id': 979,
#   'name': 'Arctia villica',
#   'common_name': 'Cream-spot Tiger',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Arctia',
#   'specific_epithet': 'villica',
#   'image_dir_name': '00979_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Arctia_villica'},
#  {'id': 980,
#   'name': 'Arctia virginalis',
#   'common_name': "Ranchman's Tiger Moth",
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Arctia',
#   'specific_epithet': 'virginalis',
#   'image_dir_name': '00980_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Arctia_virginalis'},
#  {'id': 981,
#   'name': 'Ascalapha odorata',
#   'common_name': 'Black Witch',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Ascalapha',
#   'specific_epithet': 'odorata',
#   'image_dir_name': '00981_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Ascalapha_odorata'},
#  {'id': 982,
#   'name': 'Asota caricae',
#   'common_name': 'Tropical Tiger Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Asota',
#   'specific_epithet': 'caricae',
#   'image_dir_name': '00982_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Asota_caricae'},
#  {'id': 983,
#   'name': 'Asota heliconia',
#   'common_name': 'Asota heliconia',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Asota',
#   'specific_epithet': 'heliconia',
#   'image_dir_name': '00983_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Asota_heliconia'},
#  {'id': 984,
#   'name': 'Atolmis rubricollis',
#   'common_name': 'Red-necked Footman',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Atolmis',
#   'specific_epithet': 'rubricollis',
#   'image_dir_name': '00984_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Atolmis_rubricollis'},
#  {'id': 985,
#   'name': 'Bleptina caradrinalis',
#   'common_name': 'Bent-winged Owlet',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Bleptina',
#   'specific_epithet': 'caradrinalis',
#   'image_dir_name': '00985_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Bleptina_caradrinalis'},
#  {'id': 986,
#   'name': 'Brunia antica',
#   'common_name': 'Brunia antica',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Brunia',
#   'specific_epithet': 'antica',
#   'image_dir_name': '00986_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Brunia_antica'},
#  {'id': 987,
#   'name': 'Bulia deducta',
#   'common_name': 'Deduced Graphic',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Bulia',
#   'specific_epithet': 'deducta',
#   'image_dir_name': '00987_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Bulia_deducta'},
#  {'id': 988,
#   'name': 'Caenurgia chloropha',
#   'common_name': 'Vetch Looper Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Caenurgia',
#   'specific_epithet': 'chloropha',
#   'image_dir_name': '00988_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Caenurgia_chloropha'},
#  {'id': 989,
#   'name': 'Caenurgina crassiuscula',
#   'common_name': 'Clover Looper Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Caenurgina',
#   'specific_epithet': 'crassiuscula',
#   'image_dir_name': '00989_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Caenurgina_crassiuscula'},
#  {'id': 990,
#   'name': 'Caenurgina erechtea',
#   'common_name': 'Forage Looper Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Caenurgina',
#   'specific_epithet': 'erechtea',
#   'image_dir_name': '00990_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Caenurgina_erechtea'},
#  {'id': 991,
#   'name': 'Callimorpha dominula',
#   'common_name': 'Scarlet Tiger',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Callimorpha',
#   'specific_epithet': 'dominula',
#   'image_dir_name': '00991_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Callimorpha_dominula'},
#  {'id': 992,
#   'name': 'Callistege mi',
#   'common_name': 'Mother Shipton',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Callistege',
#   'specific_epithet': 'mi',
#   'image_dir_name': '00992_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Callistege_mi'},
#  {'id': 993,
#   'name': 'Calliteara pudibunda',
#   'common_name': 'Pale Tussock Moth',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Calliteara',
#   'specific_epithet': 'pudibunda',
#   'image_dir_name': '00993_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Calliteara_pudibunda'},
#  {'id': 994,
#   'name': 'Catocala amatrix',
#   'common_name': 'The Sweetheart',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Catocala',
#   'specific_epithet': 'amatrix',
#   'image_dir_name': '00994_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Catocala_amatrix'},
#  {'id': 995,
#   'name': 'Catocala cara',
#   'common_name': 'Darling Underwing',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Catocala',
#   'specific_epithet': 'cara',
#   'image_dir_name': '00995_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Catocala_cara'},
#  {'id': 996,
#   'name': 'Catocala concumbens',
#   'common_name': 'Pink Underwing',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Catocala',
#   'specific_epithet': 'concumbens',
#   'image_dir_name': '00996_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Catocala_concumbens'},
#  {'id': 997,
#   'name': 'Catocala grynea',
#   'common_name': 'Woody Underwing',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Catocala',
#   'specific_epithet': 'grynea',
#   'image_dir_name': '00997_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Catocala_grynea'},
#  {'id': 998,
#   'name': 'Catocala ilia',
#   'common_name': 'Ilia Underwing',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Catocala',
#   'specific_epithet': 'ilia',
#   'image_dir_name': '00998_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Catocala_ilia'},
#  {'id': 999,
#   'name': 'Catocala lineella',
#   'common_name': 'Little Lined Underwing',
#   'supercategory': 'Insects',
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta',
#   'order': 'Lepidoptera',
#   'family': 'Erebidae',
#   'genus': 'Catocala',
#   'specific_epithet': 'lineella',
#   'image_dir_name': '00999_Animalia_Arthropoda_Insecta_Lepidoptera_Erebidae_Catocala_lineella'},
#  ...]

# %%
order_dict = {v: k for k, v in test.id_to_order.items()}

# %%
y_pred_labeled = [data["categories"][order_dict[y]]["name"] for y in y_pred]
y_true_labeled = [data["categories"][order_dict[y]]["name"] for y in y_true]

# %%
labels = [data["categories"][k]["name"] for k in test.id_to_order.keys()]
labels
# Out:
# ['Amia calva',
#  'Anguilla rostrata',
#  'Gymnothorax prasinus',
#  'Latropiscis purpurissatus',
#  'Dorosoma cepedianum',
#  'Catostomus commersonii',
#  'Campostoma anomalum',
#  'Carassius auratus',
#  'Cyprinus carpio',
#  'Cyprinus rubrofuscus',
#  'Luxilus chrysocephalus',
#  'Luxilus cornutus',
#  'Notemigonus crysoleucas',
#  'Pimephales notatus',
#  'Rhinichthys atratulus',
#  'Scardinius erythrophthalmus',
#  'Semotilus atromaculatus',
#  'Squalius cephalus',
#  'Cyprinodon variegatus',
#  'Fundulus diaphanus',
#  'Fundulus heteroclitus',
#  'Fundulus notatus',
#  'Gambusia affinis',
#  'Gambusia holbrooki',
#  'Megalops atlanticus',
#  'Esox lucius',
#  'Esox niger',
#  'Culaea inconstans',
#  'Gasterosteus aculeatus',
#  'Gobiesox maeandricus',
#  'Lepisosteus oculatus',
#  'Lepisosteus osseus',
#  'Lepisosteus platyrhincus',
#  'Mugil cephalus',
#  'Acanthurus coeruleus',
#  'Acanthurus nigrofuscus',
#  'Acanthurus olivaceus',
#  'Acanthurus triostegus',
#  'Naso lituratus',
#  'Zebrasoma flavescens',
#  'Ostorhinchus limenus',
#  'Pseudocaranx georgianus',
#  'Trachurus novaezelandiae',
#  'Ambloplites rupestris',
#  'Lepomis auritus',
#  'Lepomis cyanellus',
#  'Lepomis gibbosus',
#  'Lepomis gulosus',
#  'Lepomis macrochirus',
#  'Lepomis megalotis',
#  'Lepomis microlophus',
#  'Micropterus dolomieu',
#  'Micropterus salmoides',
#  'Pomoxis annularis',
#  'Pomoxis nigromaculatus',
#  'Chaetodon auriga',
#  'Chaetodon capistratus',
#  'Cheilodactylus fuscus',
#  'Cheilodactylus nigripes',
#  'Cheilodactylus vestitus',
#  'Herichthys cyanoguttatus',
#  'Mayaheros urophthalmus',
#  'Oreochromis mossambicus',
#  'Oreochromis niloticus',
#  'Cirrhitichthys aprinus',
#  'Dinolestes lewini',
#  'Enoplosus armatus',
#  'Girella nigricans',
#  'Girella tricuspidata',
#  'Girella zebra',
#  'Neogobius melanostomus',
#  'Haemulon flavolineatum',
#  'Haemulon sciurus',
#  'Atypichthys strigatus',
#  'Microcanthus strigatus',
#  'Scorpis lineolata',
#  'Tilodon sexfasciatus',
#  'Achoerodus viridis',
#  'Bodianus diplotaenia',
#  'Coris julis',
#  'Eupetrichthys angustipes',
#  'Halichoeres bivittatus',
#  'Labroides dimidiatus',
#  'Notolabrus gymnogenis',
#  'Ophthalmolepis lineolata',
#  'Pictilabrus laticlavius',
#  'Pseudolabrus guentheri',
#  'Thalassoma bifasciatum',
#  'Thalassoma hardwicke',
#  'Thalassoma lucasanum',
#  'Thalassoma lunare',
#  'Thalassoma pavo',
#  'Lutjanus apodus',
#  'Lutjanus griseus',
#  'Ocyurus chrysurus',
#  'Schuettea scalaripinnis',
#  'Morone americana',
#  'Morone saxatilis',
#  'Mullus surmuletus',
#  'Parupeneus spilurus',
#  'Upeneichthys lineatus',
#  'Etheostoma caeruleum',
#  'Perca flavescens',
#  'Perca fluviatilis',
#  'Sander vitreus',
#  'Trachinops taeniatus',
#  'Pomacanthus paru',
#  'Abudefduf saxatilis',
#  'Abudefduf sexfasciatus',
#  'Abudefduf troschelii',
#  'Abudefduf vaigiensis',
#  'Amphiprion clarkii',
#  'Chromis chromis',
#  'Dascyllus trimaculatus',
#  'Hypsypops rubicundus',
#  'Mecaenichthys immaculatus',
#  'Microspathodon chrysurus',
#  'Parma microlepis',
#  'Pomatomus saltatrix',
#  'Scarus ghobban',
#  'Sparisoma aurofrenatum',
#  'Sparisoma viride',
#  'Aplodinotus grunniens',
#  'Cynoscion nebulosus',
#  'Micropogonias undulatus',
#  'Pogonias cromis',
#  'Sciaenops ocellatus',
#  'Hypoplectrodes maccullochi',
#  'Paralabrax clathratus',
#  'Serranus scriba',
#  'Acanthopagrus australis',
#  'Archosargus probatocephalus',
#  'Chrysophrys auratus',
#  'Diplodus sargus',
#  'Diplodus vulgaris',
#  'Lagodon rhomboides',
#  'Oblada melanura',
#  'Sarpa salpa',
#  'Sphyraena barracuda',
#  'Enneapterygius atrogulare',
#  'Forsterygion lapillum',
#  'Zanclus cornutus',
#  'Oncorhynchus clarkii',
#  'Oncorhynchus kisutch',
#  'Oncorhynchus mykiss',
#  'Oncorhynchus nerka',
#  'Oncorhynchus tshawytscha',
#  'Salmo trutta',
#  'Salvelinus fontinalis',
#  'Oligocottus maculosus',
#  'Platycephalus fuscus',
#  'Pterois volitans',
#  'Scorpaena jacksoniensis',
#  'Ariopsis felis',
#  'Ameiurus melas',
#  'Ameiurus natalis',
#  'Ameiurus nebulosus',
#  'Ictalurus punctatus',
#  'Plotosus lineatus',
#  'Aulostomus chinensis',
#  'Aulostomus maculatus',
#  'Fistularia commersonii',
#  'Hippocampus abdominalis',
#  'Hippocampus histrix',
#  'Hippocampus whitei',
#  'Phycodurus eques',
#  'Phyllopteryx taeniolatus',
#  'Anoplocapros inermis',
#  'Chilomycterus schoepfii',
#  'Dicotylichthys punctulatus',
#  'Diodon holocanthus',
#  'Diodon hystrix',
#  'Mola mola',
#  'Brachaluteres jacksonianus',
#  'Meuschenia freycineti',
#  'Meuschenia trachylepis',
#  'Monacanthus chinensis',
#  'Lactophrys triqueter',
#  'Ostracion cubicus',
#  'Ostracion meleagris',
#  'Arothron hispidus',
#  'Arothron meleagris',
#  'Tetractenos glaber',
#  'Triaenodon obesus',
#  'Triakis semifasciata',
#  'Heterodontus portusjacksoni',
#  'Carcharias taurus',
#  'Aetobatus narinari',
#  'Bathytoshia brevicaudata',
#  'Hypanus americanus',
#  'Taeniura lymma',
#  'Myliobatis californica',
#  'Myliobatis tenuicaudatus',
#  'Trygonoptera testacea',
#  'Urobatis halleri',
#  'Ginglymostoma cirratum',
#  'Orectolobus halei',
#  'Orectolobus maculatus',
#  'Trygonorrhina fasciata']

# %%
# Create the confusion matrix
cm = confusion_matrix(y_true_labeled, y_pred_labeled)

# %%
plt.figure(figsize = (64,32))
sns.heatmap(cm, square=True, xticklabels=labels, yticklabels=labels)
plt.title("Confusion Matrix")
plt.show()

# %%
cm_small = confusion_matrix(y_true_labeled, y_pred_labeled)[90:110,90:110]
labels_small = labels[90:110]

# %%
plt.figure(figsize = (20,16))
sns.heatmap(cm_small, square=True, xticklabels=labels_small, yticklabels=labels_small)
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_true_labeled, y_pred_labeled))
# Out:
#                              precision    recall  f1-score   support
#
#         Abudefduf saxatilis       0.15      0.20      0.17        10
#      Abudefduf sexfasciatus       0.73      0.80      0.76        10
#        Abudefduf troschelii       0.33      0.20      0.25        10
#        Abudefduf vaigiensis       0.46      0.60      0.52        10
#     Acanthopagrus australis       0.70      0.70      0.70        10
#        Acanthurus coeruleus       0.60      0.60      0.60        10
#      Acanthurus nigrofuscus       0.64      0.70      0.67        10
#        Acanthurus olivaceus       0.78      0.70      0.74        10
#       Acanthurus triostegus       0.86      0.60      0.71        10
#          Achoerodus viridis       0.54      0.70      0.61        10
#          Aetobatus narinari       0.80      0.80      0.80        10
#       Ambloplites rupestris       0.60      0.60      0.60        10
#              Ameiurus melas       0.50      0.60      0.55        10
#            Ameiurus natalis       0.50      0.30      0.38        10
#          Ameiurus nebulosus       0.36      0.50      0.42        10
#                  Amia calva       0.42      0.50      0.45        10
#          Amphiprion clarkii       0.71      1.00      0.83        10
#           Anguilla rostrata       0.23      0.30      0.26        10
#        Anoplocapros inermis       0.78      0.70      0.74        10
#       Aplodinotus grunniens       0.56      0.50      0.53        10
# Archosargus probatocephalus       0.67      0.40      0.50        10
#              Ariopsis felis       0.38      0.30      0.33        10
#           Arothron hispidus       0.50      0.40      0.44        10
#          Arothron meleagris       0.60      0.30      0.40        10
#       Atypichthys strigatus       0.67      0.60      0.63        10
#        Aulostomus chinensis       0.44      0.40      0.42        10
#        Aulostomus maculatus       0.50      0.70      0.58        10
#    Bathytoshia brevicaudata       0.36      0.50      0.42        10
#        Bodianus diplotaenia       0.71      0.50      0.59        10
#  Brachaluteres jacksonianus       0.54      0.70      0.61        10
#         Campostoma anomalum       0.56      0.50      0.53        10
#           Carassius auratus       0.36      0.40      0.38        10
#           Carcharias taurus       0.44      0.40      0.42        10
#      Catostomus commersonii       0.14      0.20      0.17        10
#            Chaetodon auriga       0.70      0.70      0.70        10
#       Chaetodon capistratus       0.58      0.70      0.64        10
#       Cheilodactylus fuscus       0.62      0.50      0.56        10
#     Cheilodactylus nigripes       0.60      0.90      0.72        10
#     Cheilodactylus vestitus       0.86      0.60      0.71        10
#     Chilomycterus schoepfii       0.60      0.30      0.40        10
#             Chromis chromis       1.00      0.50      0.67        10
#         Chrysophrys auratus       0.33      0.40      0.36        10
#      Cirrhitichthys aprinus       1.00      0.70      0.82        10
#                 Coris julis       0.67      0.80      0.73        10
#           Culaea inconstans       0.45      0.50      0.48        10
#         Cynoscion nebulosus       0.29      0.20      0.24        10
#       Cyprinodon variegatus       0.38      0.50      0.43        10
#             Cyprinus carpio       0.12      0.20      0.15        10
#        Cyprinus rubrofuscus       0.62      0.80      0.70        10
#      Dascyllus trimaculatus       0.50      0.70      0.58        10
#  Dicotylichthys punctulatus       0.78      0.70      0.74        10
#           Dinolestes lewini       0.62      0.80      0.70        10
#          Diodon holocanthus       0.45      0.50      0.48        10
#              Diodon hystrix       0.29      0.20      0.24        10
#             Diplodus sargus       0.75      0.60      0.67        10
#           Diplodus vulgaris       0.67      0.60      0.63        10
#         Dorosoma cepedianum       0.40      0.40      0.40        10
#   Enneapterygius atrogulare       0.57      0.40      0.47        10
#           Enoplosus armatus       0.64      0.70      0.67        10
#                 Esox lucius       0.23      0.30      0.26        10
#                  Esox niger       0.25      0.40      0.31        10
#        Etheostoma caeruleum       0.56      0.50      0.53        10
#    Eupetrichthys angustipes       0.78      0.70      0.74        10
#      Fistularia commersonii       0.60      0.90      0.72        10
#       Forsterygion lapillum       0.29      0.20      0.24        10
#          Fundulus diaphanus       0.33      0.30      0.32        10
#       Fundulus heteroclitus       0.25      0.20      0.22        10
#            Fundulus notatus       0.67      0.60      0.63        10
#            Gambusia affinis       0.23      0.50      0.31        10
#          Gambusia holbrooki       0.22      0.20      0.21        10
#      Gasterosteus aculeatus       0.38      0.30      0.33        10
#      Ginglymostoma cirratum       0.50      0.50      0.50        10
#           Girella nigricans       0.60      0.60      0.60        10
#        Girella tricuspidata       0.45      0.50      0.48        10
#               Girella zebra       0.67      0.40      0.50        10
#        Gobiesox maeandricus       0.56      0.50      0.53        10
#        Gymnothorax prasinus       0.90      0.90      0.90        10
#      Haemulon flavolineatum       0.50      0.60      0.55        10
#            Haemulon sciurus       0.55      0.60      0.57        10
#      Halichoeres bivittatus       0.50      0.60      0.55        10
#    Herichthys cyanoguttatus       0.60      0.30      0.40        10
# Heterodontus portusjacksoni       0.43      0.30      0.35        10
#     Hippocampus abdominalis       0.20      0.20      0.20        10
#         Hippocampus histrix       0.86      0.60      0.71        10
#          Hippocampus whitei       0.33      0.40      0.36        10
#          Hypanus americanus       0.44      0.70      0.54        10
#  Hypoplectrodes maccullochi       0.75      0.60      0.67        10
#        Hypsypops rubicundus       0.75      0.60      0.67        10
#         Ictalurus punctatus       0.16      0.40      0.23        10
#        Labroides dimidiatus       0.73      0.80      0.76        10
#        Lactophrys triqueter       0.80      0.80      0.80        10
#          Lagodon rhomboides       0.80      0.80      0.80        10
#   Latropiscis purpurissatus       0.71      0.50      0.59        10
#        Lepisosteus oculatus       0.42      0.50      0.45        10
#          Lepisosteus osseus       0.25      0.30      0.27        10
#    Lepisosteus platyrhincus       0.40      0.40      0.40        10
#             Lepomis auritus       0.75      0.60      0.67        10
#           Lepomis cyanellus       0.29      0.40      0.33        10
#            Lepomis gibbosus       0.60      0.60      0.60        10
#             Lepomis gulosus       0.57      0.40      0.47        10
#         Lepomis macrochirus       0.31      0.40      0.35        10
#           Lepomis megalotis       0.64      0.70      0.67        10
#         Lepomis microlophus       0.38      0.30      0.33        10
#             Lutjanus apodus       0.62      0.80      0.70        10
#            Lutjanus griseus       0.40      0.40      0.40        10
#      Luxilus chrysocephalus       0.50      0.30      0.38        10
#            Luxilus cornutus       0.30      0.30      0.30        10
#      Mayaheros urophthalmus       0.40      0.20      0.27        10
#   Mecaenichthys immaculatus       1.00      1.00      1.00        10
#         Megalops atlanticus       0.50      0.50      0.50        10
#       Meuschenia freycineti       0.44      0.40      0.42        10
#      Meuschenia trachylepis       0.67      0.40      0.50        10
#      Microcanthus strigatus       0.70      0.70      0.70        10
#     Micropogonias undulatus       0.57      0.40      0.47        10
#        Micropterus dolomieu       0.25      0.40      0.31        10
#       Micropterus salmoides       0.43      0.60      0.50        10
#    Microspathodon chrysurus       0.50      0.50      0.50        10
#                   Mola mola       0.43      0.60      0.50        10
#       Monacanthus chinensis       0.45      0.50      0.48        10
#            Morone americana       0.44      0.40      0.42        10
#            Morone saxatilis       0.42      0.50      0.45        10
#              Mugil cephalus       0.60      0.60      0.60        10
#           Mullus surmuletus       0.57      0.40      0.47        10
#      Myliobatis californica       0.36      0.40      0.38        10
#    Myliobatis tenuicaudatus       0.14      0.10      0.12        10
#              Naso lituratus       0.53      0.90      0.67        10
#      Neogobius melanostomus       0.43      0.30      0.35        10
#     Notemigonus crysoleucas       0.43      0.60      0.50        10
#       Notolabrus gymnogenis       0.50      0.50      0.50        10
#             Oblada melanura       0.78      0.70      0.74        10
#           Ocyurus chrysurus       0.73      0.80      0.76        10
#       Oligocottus maculosus       0.21      0.40      0.28        10
#        Oncorhynchus clarkii       0.56      0.50      0.53        10
#        Oncorhynchus kisutch       0.50      0.10      0.17        10
#         Oncorhynchus mykiss       0.12      0.20      0.15        10
#          Oncorhynchus nerka       0.38      0.30      0.33        10
#    Oncorhynchus tshawytscha       0.29      0.40      0.33        10
#    Ophthalmolepis lineolata       0.70      0.70      0.70        10
#           Orectolobus halei       0.50      0.30      0.38        10
#       Orectolobus maculatus       0.44      0.70      0.54        10
#     Oreochromis mossambicus       0.33      0.20      0.25        10
#       Oreochromis niloticus       0.20      0.10      0.13        10
#        Ostorhinchus limenus       0.80      0.80      0.80        10
#           Ostracion cubicus       0.80      0.40      0.53        10
#         Ostracion meleagris       0.54      0.70      0.61        10
#       Paralabrax clathratus       0.67      0.40      0.50        10
#            Parma microlepis       0.75      0.60      0.67        10
#         Parupeneus spilurus       0.50      0.60      0.55        10
#            Perca flavescens       0.27      0.40      0.32        10
#           Perca fluviatilis       0.29      0.40      0.33        10
#            Phycodurus eques       0.70      0.70      0.70        10
#    Phyllopteryx taeniolatus       0.83      0.50      0.62        10
#     Pictilabrus laticlavius       0.71      0.50      0.59        10
#          Pimephales notatus       0.43      0.30      0.35        10
#        Platycephalus fuscus       0.56      0.50      0.53        10
#           Plotosus lineatus       0.57      0.40      0.47        10
#             Pogonias cromis       0.38      0.50      0.43        10
#            Pomacanthus paru       0.73      0.80      0.76        10
#         Pomatomus saltatrix       0.33      0.30      0.32        10
#           Pomoxis annularis       0.75      0.30      0.43        10
#      Pomoxis nigromaculatus       0.67      0.60      0.63        10
#     Pseudocaranx georgianus       0.50      0.40      0.44        10
#      Pseudolabrus guentheri       1.00      0.60      0.75        10
#            Pterois volitans       0.60      0.60      0.60        10
#       Rhinichthys atratulus       0.43      0.30      0.35        10
#                Salmo trutta       0.14      0.10      0.12        10
#       Salvelinus fontinalis       0.31      0.40      0.35        10
#              Sander vitreus       0.50      0.30      0.38        10
#                 Sarpa salpa       0.30      0.30      0.30        10
# Scardinius erythrophthalmus       0.71      0.50      0.59        10
#              Scarus ghobban       0.89      0.80      0.84        10
#     Schuettea scalaripinnis       0.70      0.70      0.70        10
#         Sciaenops ocellatus       0.71      0.50      0.59        10
#     Scorpaena jacksoniensis       0.62      0.80      0.70        10
#           Scorpis lineolata       0.29      0.40      0.33        10
#     Semotilus atromaculatus       0.25      0.30      0.27        10
#             Serranus scriba       0.70      0.70      0.70        10
#      Sparisoma aurofrenatum       0.38      0.30      0.33        10
#            Sparisoma viride       0.70      0.70      0.70        10
#         Sphyraena barracuda       0.38      0.30      0.33        10
#           Squalius cephalus       0.38      0.30      0.33        10
#              Taeniura lymma       0.78      0.70      0.74        10
#          Tetractenos glaber       0.38      0.30      0.33        10
#      Thalassoma bifasciatum       0.47      0.70      0.56        10
#        Thalassoma hardwicke       0.50      0.60      0.55        10
#        Thalassoma lucasanum       0.33      0.10      0.15        10
#           Thalassoma lunare       0.75      0.60      0.67        10
#             Thalassoma pavo       0.50      0.80      0.62        10
#        Tilodon sexfasciatus       0.75      0.60      0.67        10
#        Trachinops taeniatus       0.67      1.00      0.80        10
#    Trachurus novaezelandiae       0.80      0.40      0.53        10
#           Triaenodon obesus       0.33      0.30      0.32        10
#        Triakis semifasciata       0.12      0.10      0.11        10
#       Trygonoptera testacea       1.00      0.40      0.57        10
#      Trygonorrhina fasciata       0.89      0.80      0.84        10
#       Upeneichthys lineatus       0.77      1.00      0.87        10
#            Urobatis halleri       0.40      0.40      0.40        10
#            Zanclus cornutus       0.78      0.70      0.74        10
#        Zebrasoma flavescens       0.71      0.50      0.59        10
#
#                    accuracy                           0.51      1990
#                   macro avg       0.53      0.51      0.51      1990
#                weighted avg       0.53      0.51      0.51      1990

# %%
import pandas as pd

report = classification_report(y_true_labeled, y_pred_labeled, output_dict=True)
report_df = pd.DataFrame(report).transpose()

# %%
report_df.sort_values(by="f1-score", ascending=False)
# Out:
#                            precision  recall  f1-score  support
# Mecaenichthys immaculatus   1.000000     1.0  1.000000     10.0
# Gymnothorax prasinus        0.900000     0.9  0.900000     10.0
# Upeneichthys lineatus       0.769231     1.0  0.869565     10.0
# Scarus ghobban              0.888889     0.8  0.842105     10.0
# Trygonorrhina fasciata      0.888889     0.8  0.842105     10.0
# ...                              ...     ...       ...      ...
# Oncorhynchus mykiss         0.117647     0.2  0.148148     10.0
# Oreochromis niloticus       0.200000     0.1  0.133333     10.0
# Myliobatis tenuicaudatus    0.142857     0.1  0.117647     10.0
# Salmo trutta                0.142857     0.1  0.117647     10.0
# Triakis semifasciata        0.125000     0.1  0.111111     10.0
#
# [202 rows x 4 columns]

# %%
output = pipeline.predict("/home/nates/repos/inaturalist-species-detection/data/val/02789_Animalia_Chordata_Actinopterygii_Mugiliformes_Mugilidae_Mugil_cephalus/9f847924-7d56-4720-b5fb-f2ef5385078d.jpg")

# %%
data["categories"][output]["name"]
# Out:
# 'Ixodes scapularis'

# %%
report_df["f1-score"].plot(kind="hist", bins=15, xlabel="F1 Score", figsize=(5,4))
# Out:
# <Axes: xlabel='F1 Score', ylabel='Frequency'>

# %%
report_df.drop(columns=["support"]).sort_values(by="f1-score", ascending=False).head().plot(kind="bar", ylim=(0,1), figsize=(5,4))
# Out:
# <Axes: >

# %%
report_df.drop(columns=["support"]).sort_values(by="f1-score", ascending=False).tail().plot(kind="bar", ylim=(0,1), figsize=(5,4))
# Out:
# <Axes: >

# %%
report_df.drop(columns=["support"]).sort_values(by="f1-score", ascending=False).tail()
# Out:
#                           precision  recall  f1-score
# Oncorhynchus mykiss        0.117647     0.2  0.148148
# Oreochromis niloticus      0.200000     0.1  0.133333
# Myliobatis tenuicaudatus   0.142857     0.1  0.117647
# Salmo trutta               0.142857     0.1  0.117647
# Triakis semifasciata       0.125000     0.1  0.111111
