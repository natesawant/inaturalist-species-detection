# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
efficient_df = pd.read_csv("train_efficient_fish_latest.csv").set_index("epoch")
transformer_df = pd.read_csv("train.csv").set_index("epoch")

# %%
efficient_df = efficient_df[:20]

# %%
efficient_df
# Out:
#            loss      top-1      top-5
# epoch
# 0      5.367525   0.653266   2.160804
# 1      1.977273  38.693467  68.643216
# 2      1.772297  45.376884  72.512563
# 3      1.584955  47.487437  74.773869
# 4      1.367525  49.748744  75.226131
# 5      1.571318  50.201005  75.728643
# 6      1.330159  52.613065  75.879397
# 7      1.220321  51.105528  75.477387
# 8      1.186813  50.954774  75.577889
# 9      1.006710  50.603015  75.226131
# 10     1.045872  52.311558  75.025126
# 11     0.907038  51.206030  76.030151
# 12     0.797790  52.160804  76.231156
# 13     0.719349  51.407035  75.879397
# 14     1.097839  51.356784  75.778894
# 15     0.559548  51.608040  75.527638
# 16     0.501131  52.412060  75.025126
# 17     0.671238  52.663317  75.025126
# 18     0.346407  50.653266  75.125628
# 19     0.590243  51.608040  74.321608

# %%
transformer_df
# Out:
#            loss      top-1      top-5
# epoch
# 0      5.927497   0.452261   2.160804
# 1      1.826495  50.351759  74.874372
# 2      1.388370  53.919598  76.281407
# 3      1.398225  55.778894  77.487437
# 4      1.246525  56.080402  77.788945
# 5      0.886229  56.231156  78.190955
# 6      0.989897  56.733668  77.537688
# 7      1.041700  56.633166  78.140704
# 8      0.927497  56.934673  78.592965
# 9      1.005302  56.080402  77.788945
# 9      0.741533  56.231156  76.532663
# 10     0.662520  55.678392  76.884422
# 11     0.926661  54.974874  76.733668
# 12     0.560924  55.829146  77.085427
# 13     0.566652  55.929648  77.035176
# 14     0.508850  54.974874  77.437186
# 15     0.752538  55.678392  77.185930
# 16     0.451824  55.075377  77.688442
# 17     0.615945  55.427136  76.432161
# 18     0.414729  55.125628  77.085427
# 19     0.675504  54.170854  76.130653

# %%
plt.figure(figsize=(16,12))
plt.plot(transformer_df)
plt.plot(efficient_df)
plt.legend(["ViT Loss", "ViT Top 1 Accuracy", "ViT Top 5 Accuracy", "EfficientNet Loss", "EfficientNet Top 1 Accuracy", "EfficientNet Top 5 Accuracy"])
plt.title("EfficientNet vs Transformer Loss, Top 1 and Top 5 Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.ylim((0, 100))
plt.tight_layout(pad=50)
plt.show()
# Out:
# /tmp/ipykernel_86539/3172673737.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(pad=50)
